# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data set

# %%
data = pd.read_csv('../raw_data/Tokyo_Restaurant_Reviews_Tabelog.csv')

# %%
data.head(1)
# Out:
#    store_id                name nearest_station  nearest_distance  \
# 0  13097553  個室北国炉端 ときしらず 飯田橋駅前            飯田橋駅              82.0
#
#                             genre  rating_val  review_cnt  save_cnt  \
# 0  魚介料理・海鮮料理、居酒屋、日本料理                    3.12        61.0    2848.0
#
#    budget_dinner   budget_lunch holiday                  address prefecture  \
# 0  ￥3,000～￥3,999  ￥3,000～￥3,999       -  東京都千代田区飯田橋4-9-8 大和ビル 5F         東京
#
#   municipalities_1 municipalities_2 municipalities_3
# 0             千代田区              飯田橋                -

# %% [markdown]
# # Feature Engeneering

# %%
#choose what Data is going to be relevent to the project

data_clean = data[['store_id', 'name','genre', 'rating_val','review_cnt','budget_dinner', 'budget_lunch','address']]

# %%
data_clean.head()
# Out:
#    store_id                   name                           genre  \
# 0  13097553     個室北国炉端 ときしらず 飯田橋駅前  魚介料理・海鮮料理、居酒屋、日本料理
# 1  13115133              祭 飯田橋東口駅前      居酒屋、和食（その他）、焼鳥
# 2  13139364                 鳥酎 飯田橋        焼鳥、居酒屋、日本酒バー
# 3  13260247         炭火焼き鳥 すいけん 飯田橋        居酒屋、焼鳥、日本酒バー
# 4  13225614  個室居酒屋×博多焼き鳥 巻きの助 飯田橋店          居酒屋、焼鳥、もつ鍋
#
#    rating_val  review_cnt  budget_dinner   budget_lunch  \
# 0        3.12        61.0  ￥3,000～￥3,999  ￥3,000～￥3,999
# 1        3.25        29.0  ￥2,000～￥2,999              -
# 2        3.46       119.0  ￥3,000～￥3,999          ～￥999
# 3        3.06        14.0  ￥2,000～￥2,999  ￥1,000～￥1,999
# 4        3.07        35.0  ￥3,000～￥3,999              -
#
#                          address
# 0        東京都千代田区飯田橋4-9-8 大和ビル 5F
# 1      東京都千代田区飯田橋4-9-8 飯田橋プラザ 1F
# 2   東京都千代田区飯田橋4-7-11 カクタス飯田橋 B1F
# 3  東京都千代田区飯田橋3-3-7 秋穂セントラルビル 1-B
# 4     東京都千代田区飯田橋4-5-6 ECS第3ビル 1F

# %%
data_clean.drop_duplicates()
# Out:
#         store_id                   name                               genre  \
# 0       13097553     個室北国炉端 ときしらず 飯田橋駅前      魚介料理・海鮮料理、居酒屋、日本料理
# 1       13115133              祭 飯田橋東口駅前          居酒屋、和食（その他）、焼鳥
# 2       13139364                 鳥酎 飯田橋            焼鳥、居酒屋、日本酒バー
# 3       13260247         炭火焼き鳥 すいけん 飯田橋            居酒屋、焼鳥、日本酒バー
# 4       13225614  個室居酒屋×博多焼き鳥 巻きの助 飯田橋店              居酒屋、焼鳥、もつ鍋
# ...          ...                    ...                                 ...
# 125917  13269978                88 cafe                     カフェ
# 125918  13245445               お食事処 めぐろ  居酒屋・ダイニングバー（その他）、定食・食堂
# 125919  13272172        アンナビーチ母島ユースホステル                     その他
# 125920  13272155       アイランドリゾート母島 ナンプー                      旅館
# 125921  13269979                    島っ娘                     居酒屋
#
#         rating_val  review_cnt  budget_dinner   budget_lunch  \
# 0             3.12        61.0  ￥3,000～￥3,999  ￥3,000～￥3,999
# ...

# %%
data['rating_val'].median()
# Out:
# 3.09

# %% [markdown]
# ## Filling NaN values

# %%
# Filling the NaN value of Rating with the mean value of all the ratings. 
data_clean['rating_val'].fillna(3.09, inplace=True)
# Out:
# /tmp/ipykernel_1232/3004390699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean['rating_val'].fillna(3.09, inplace=True)

# %%
data_clean['rating_val']
# Out:
# 0         3.12
# 1         3.25
# 2         3.46
# 3         3.06
# 4         3.07
#           ...
# 125917    3.03
# 125918    3.05
# 125919    3.09
# 125920    3.09
# 125921    3.09
# Name: rating_val, Length: 125922, dtype: float64

# %%
data_clean.head()
# Out:
#    store_id                   name                           genre  \
# 0  13097553     個室北国炉端 ときしらず 飯田橋駅前  魚介料理・海鮮料理、居酒屋、日本料理
# 1  13115133              祭 飯田橋東口駅前      居酒屋、和食（その他）、焼鳥
# 2  13139364                 鳥酎 飯田橋        焼鳥、居酒屋、日本酒バー
# 3  13260247         炭火焼き鳥 すいけん 飯田橋        居酒屋、焼鳥、日本酒バー
# 4  13225614  個室居酒屋×博多焼き鳥 巻きの助 飯田橋店          居酒屋、焼鳥、もつ鍋
#
#    rating_val  review_cnt  budget_dinner   budget_lunch  \
# 0        3.12        61.0  ￥3,000～￥3,999  ￥3,000～￥3,999
# 1        3.25        29.0  ￥2,000～￥2,999              -
# 2        3.46       119.0  ￥3,000～￥3,999          ～￥999
# 3        3.06        14.0  ￥2,000～￥2,999  ￥1,000～￥1,999
# 4        3.07        35.0  ￥3,000～￥3,999              -
#
#                          address
# 0        東京都千代田区飯田橋4-9-8 大和ビル 5F
# 1      東京都千代田区飯田橋4-9-8 飯田橋プラザ 1F
# 2   東京都千代田区飯田橋4-7-11 カクタス飯田橋 B1F
# 3  東京都千代田区飯田橋3-3-7 秋穂セントラルビル 1-B
# 4     東京都千代田区飯田橋4-5-6 ECS第3ビル 1F

# %% [markdown]
# ### Now filling the review_cnt with one becasue I gave it the rating

# %%
data_clean['review_cnt'].fillna(1.0, inplace=True)
# Out:
# /tmp/ipykernel_1232/3548856892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean['review_cnt'].fillna(1.0, inplace=True)

# %%
data_clean.head(20)
# Out:
#     store_id                   name                                genre  \
# 0   13097553     個室北国炉端 ときしらず 飯田橋駅前       魚介料理・海鮮料理、居酒屋、日本料理
# 1   13115133              祭 飯田橋東口駅前           居酒屋、和食（その他）、焼鳥
# 2   13139364                 鳥酎 飯田橋             焼鳥、居酒屋、日本酒バー
# 3   13260247         炭火焼き鳥 すいけん 飯田橋             居酒屋、焼鳥、日本酒バー
# 4   13225614  個室居酒屋×博多焼き鳥 巻きの助 飯田橋店               居酒屋、焼鳥、もつ鍋
# 5   13158568  シーフードビストロ 魚卵House Eni         バル・バール、パスタ、イタリアン
# 6   13234632               やきとりあそび邸         焼鳥、魚介料理・海鮮料理、居酒屋
# 7   13158520         飯田橋スペインバル ALBA        スペイン料理、居酒屋、バル・バール
# 8   13209006            鉄板居酒屋お好みキング           居酒屋、お好み焼き、鉄板焼き
# 9   13162934    個室中華 食べ飲み放題 佳宴 飯田橋店              中華料理、居酒屋、餃子
# 10  13249498       炉端焼き 大衆魚食堂才蔵 飯田橋      居酒屋、魚介料理・海鮮料理、日本酒バー
# 11  13011164                     平川           日本料理、魚介料理・海鮮料理
# 12  13178488        貸切 ダイニングバー Rupo        ダイニングバー、イタリアン、居酒屋
# 13  13202412                 飯田橋 喝采            日本料理、居酒屋、創作料理
# ...

# %%
data_clean.tail(20)
# Out:
#         store_id                    name  \
# 125902  13269980                   民宿 つき
# 125903  13131218            クラフト イン ラメーフ
# 125904  13238258                   ル シエル
# 125905  13281019                   しまてらす
# 125906  13230067  東京島しょ農業協同組合 JA小笠原島母島支店
# 125907  13272183                ドルフィン 別館
# 125908  13272194             母島水産物販売センター
# 125909  13272178                  民宿 メグロ
# 125910  13273043               ダイブリゾート母島
# 125911  13274897                    漁協売店
# 125912  13230075                    前田商店
# 125913  13272177              ペンションドルフィン
# 125914  13269977                 BOOTERS
# 125915  13272173               ペンション りゅう
# 125916  13274913               小笠原母島観光協会
# 125917  13269978                 88 cafe
# 125918  13245445                お食事処 めぐろ
# 125919  13272172         アンナビーチ母島ユースホステル
# 125920  13272155        アイランドリゾート母島 ナンプー
# 125921  13269979                     島っ娘
#
#                                             genre  rating_val  review_cnt  \
# ...

# %% [markdown]
# # Turn it into a Json file

# %%
data_clean.to_json('dataset.json', orient='records')
